# %% [markdown]
# <a href="https://colab.research.google.com/github/saifghostrider454/MachineLearningFull/blob/main/SDML(LABEL_ENCODING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# breast cancer dataset

df1 = pd.read_csv('/content/data.csv')

# iris dataset

df2 = pd.read_csv('/content/iris_data.csv')

# %%
df1.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
label = LabelEncoder()

# %%
labels = label.fit_transform(df1.diagnosis)

# %%
df1['target'] = labels

# %%
# 0 --> B and 1 --> M

df1.sample(5)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 28    852973         M        15.30         25.27          102.40      732.4
# 183   873843         B        11.41         14.92           73.53      402.0
# 425   907367         B        10.03         21.28           63.19      307.3
# 288  8913049         B        11.26         19.96           73.72      394.1
# 419   906290         B        11.16         21.41           70.95      380.3
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 28           0.10820           0.16970        0.168300             0.087510
# 183          0.09059           0.08155        0.061810             0.023610
# 425          0.08117           0.03912        0.002470             0.005159
# 288          0.08020           0.11810        0.092740             0.055880
# 419          0.10180           0.05978        0.008955             0.010760
#
# ...

# %%
df2.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 7      8            5.0           3.4            1.5           0.2
# 98    99            5.1           2.5            3.0           1.1
# 127  128            6.1           3.0            4.9           1.8
# 94    95            5.6           2.7            4.2           1.3
# 137  138            6.4           3.1            5.5           1.8
#
#              Species
# 7        Iris-setosa
# 98   Iris-versicolor
# 127   Iris-virginica
# 94   Iris-versicolor
# 137   Iris-virginica

# %%
df2['target'] = label.fit_transform(df2.Species)

# %%
df2.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 139  140            6.9           3.1            5.4           2.1
# 7      8            5.0           3.4            1.5           0.2
# 36    37            5.5           3.5            1.3           0.2
# 117  118            7.7           3.8            6.7           2.2
# 112  113            6.8           3.0            5.5           2.1
# 131  132            7.9           3.8            6.4           2.0
# 87    88            6.3           2.3            4.4           1.3
# 104  105            6.5           3.0            5.8           2.2
# 89    90            5.5           2.5            4.0           1.3
# 55    56            5.7           2.8            4.5           1.3
#
#              Species  target
# 139   Iris-virginica       2
# 7        Iris-setosa       0
# 36       Iris-setosa       0
# 117   Iris-virginica       2
# 112   Iris-virginica       2
# 131   Iris-virginica       2
# ...

# %%
df1.corr()['target']
# Out:
# <ipython-input-22-e75d4c304367>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()['target']
# id                         0.039769
# radius_mean                0.730029
# texture_mean               0.415185
# perimeter_mean             0.742636
# area_mean                  0.708984
# smoothness_mean            0.358560
# compactness_mean           0.596534
# concavity_mean             0.696360
# concave points_mean        0.776614
# symmetry_mean              0.330499
# fractal_dimension_mean    -0.012838
# radius_se                  0.567134
# texture_se                -0.008303
# perimeter_se               0.556141
# area_se                    0.548236
# smoothness_se             -0.067016
# compactness_se             0.292999
# concavity_se               0.253730
# ...
